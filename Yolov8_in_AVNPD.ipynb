# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install ultralytics
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# Import Libraries
import numpy as np
import pandas as pd
import os
import torch
from IPython.display import Image
import shutil
from random import choice
import yaml
import matplotlib.pyplot as plt
import random
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from google.colab import files
from ultralytics import YOLO
from IPython.display import HTML
from base64 import b64encode

# %%
# %cd /content/drive/MyDrive/Thesis/yolo
# Out:
# /content/drive/MyDrive/Thesis/yolo

# %%
# Train
# !yolo task=detect mode=train model=yolov8m.pt imgsz=640 data='/content/drive/MyDrive/Thesis/yolo/data.yaml' epochs=16 batch=16 project=/content/drive/MyDrive/Thesis/yolo/V8newoutput name=result
# Out:
# Ultralytics YOLOv8.1.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Train
# !yolo task=detect mode=train model=yolov8m.pt imgsz=640 data='/content/drive/MyDrive/Thesis/yolo/data.yaml' epochs=30 batch=16 project=/content/drive/MyDrive/Thesis/yolo/V8newoutput name=result2
# Out:
# Ultralytics YOLOv8.1.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Thesis/yolo/V8newoutput/result2/weights/best.pt conf=0.6 source=/content/drive/MyDrive/Thesis/yolo/data/test
# Out:
# Ultralytics YOLOv8.1.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/240 /content/drive/MyDrive/Thesis/yolo/data/test/test (1).jpg: 640x480 1 plate, 158.2ms
# image 2/240 /content/drive/MyDrive/Thesis/yolo/data/test/test (10).jpg: 640x480 1 plate, 28.2ms
# image 3/240 /content/drive/MyDrive/Thesis/yolo/data/test/test (100).jpg: 640x512 1 plate, 82.1ms
# image 4/240 /content/drive/MyDrive/Thesis/yolo/data/test/test (101).jpg: 640x512 1 plate, 28.2ms
# image 5/240 /content/drive/MyDrive/Thesis/yolo/data/test/test (102).jpg: 640x512 1 plate, 28.2ms
# image 6/240 /content/drive/MyDrive/Thesis/yolo/data/test/test (103).jpg: 640x512 1 plate, 28.1ms
# image 7/240 /content/drive/MyDrive/Thesis/yolo/data/test/test (104).jpg: 640x512 1 plate, 28.1ms
# ...

# %%
Image(filename='/content/drive/MyDrive/Thesis/yolo/V8newoutput/result2/results.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/Thesis/yolo/V8newoutput/result2/confusion_matrix.png', width=600)
